# %% [markdown]
# <a href="https://colab.research.google.com/github/rilschultz/CS167Notes/blob/main/Day20_Neural_Networks_Part_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS167: Day20
# ## Neural Networks Part III
#
# #### CS167: Machine Learning, Spring 2023
#
# Tuesday, April 11th, 2023
#
# 📆 [Course Schedule](https://docs.google.com/spreadsheets/d/e/2PACX-1vSvFV5Mz0_YZE1d5r3gQ8IMktE4cBAsJIlP30cl2GhEpSO0J-YWV62QokSDz-OcOCsEmxMuKpY0kVlR/pubhtml?gid=0&single=true) | 🙋[PollEverywhere](https://pollev.com/meredithmoore011) | 📜 [Syllabus](https://analytics.drake.edu/~moore/cs167_s23_syllabus.html) | 📬 [CodePost Login](https://codepost.io/login)

# %% [markdown]
# # Admin Stuff

# %% [markdown]
# Grading--I owe you grades for:
# - Project #1
# - Quiz #2
# - Notebook #5

# %% [markdown]
# You should be working on:
# - [Notebook #6](https://classroom.github.com/a/pUdpmxBH) is released today, due April 17th by 11:59pm

# %% [markdown]
# # Announcement
#
# __Thursday 4/13__: We'll have guest speakers from Berkshire Hathaway
#
# <div>
# <img src="https://github.com/merriekay/S23-CS167-Notes/blob/main/images/berkshire_hathaway_energy.jpeg?raw=1" width=250/>
# </div>

# %% [markdown]
# ## Load your data:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas
path = '/content/drive/MyDrive/datasets/irisData.csv'
data = pandas.read_csv(path)

# %% [markdown]
# ## Quick Review:

# %% [markdown]
# # Neural Network Summary
#
# Neural Networks are effective in __finding non-linear patterns__ in the training data.
# - can be applied to __regression__ or __classification__.
# - __backpropagation__ tunes the weights over a neural network using __gradient descent__ to iteratively reduce the error in the network.
# - __Overfitting__ the training data is common and is important to avoid.
# - The following parameters shoudl be tuned when using neural networks:
#     - number of epochs
#     - structure of the network (depth, width)
#     - activation function
#     - eta (learning rate)

# %% [markdown]
# # Training a Neural Network to Predict Taxi Fares:
#
# Download `taxi-fares.csv` from Blackboard and put it in your Google Drive. This data is from the New York City Taxi and LImousine Commision and includes data about taxi fares.
#
# Let's start by loading in our dataset and doing some pre-processing.

# %%
from math import sqrt
import pandas as pd

#load dataset
path = '/content/drive/MyDrive/datasets/taxi-fares.csv'
df = pd.read_csv(path, parse_dates=['pickup_datetime'])

# data prep
df = df[df['passenger_count'] == 1]
df = df.drop(['key', 'passenger_count'], axis=1)
 
for i, row in df.iterrows():
    dt = row['pickup_datetime']
    df.at[i, 'day_of_week'] = dt.weekday()
    df.at[i, 'pickup_time'] = dt.hour
    x = (row['dropoff_longitude'] - row['pickup_longitude']) * 54.6
    y = (row['dropoff_latitude'] - row['pickup_latitude']) * 69.0
    distance = sqrt(x**2 + y**2)
    df.at[i, 'distance'] = distance
 
df.drop(['pickup_datetime', 'pickup_longitude', 'pickup_latitude',
         'dropoff_longitude', 'dropoff_latitude'], axis=1, inplace=True)
 
df = df[(df['distance'] > 1.0) & (df['distance'] < 10.0)]
df = df[(df['fare_amount'] > 0.0) & (df['fare_amount'] < 50.0)]
df.head()
# Out:
#    fare_amount  day_of_week  pickup_time  distance
# 2          6.1          0.0         15.0  1.038136
# 4         10.5          5.0         10.0  2.924341
# 5         15.3          4.0         20.0  4.862893
# 8          7.7          5.0          1.0  2.603493
# 9          8.9          3.0         16.0  1.365739

# %% [markdown]
# ## 🙋 PollEverywhere

# %% [markdown]
# # Build Your Model:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
model = Sequential()
model.add(Dense(512, activation='relu', input_dim=3))
model.add(Dense(512, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mae', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               2048
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 265,217
# Trainable params: 265,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - What is the _depth_ of this model?
# - How many attributes are input to the model?
# - What is the _width_ of the hidden layers of this model?
# - What type of Gradient Descent is being used to train this model?
# - What metrics are we keeping track of?

# %% [markdown]
# # Now, let's train our model:

# %%
x = df.drop('fare_amount', axis=1)
y = df['fare_amount']

hist = model.fit(x, y, validation_split=0.2, epochs=50, batch_size=100)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 6s 4ms/step - loss: 2.8792 - mae: 2.8792 - val_loss: 2.4062 - val_mae: 2.4062
# Epoch 2/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4146 - mae: 2.4146 - val_loss: 2.4151 - val_mae: 2.4151
# Epoch 3/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3921 - mae: 2.3921 - val_loss: 2.3828 - val_mae: 2.3828
# Epoch 4/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3636 - mae: 2.3636 - val_loss: 2.3874 - val_mae: 2.3874
# Epoch 5/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3577 - mae: 2.3577 - val_loss: 2.5288 - val_mae: 2.5288
# Epoch 6/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3734 - mae: 2.3734 - val_loss: 2.3954 - val_mae: 2.3954
# Epoch 7/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3486 - mae: 2.3486 - val_loss: 2.3433 - val_mae: 2.3433
# Epoch 8/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3701 - mae: 2.3701 - val_loss: 2.3957 - val_mae: 2.3957
# Epoch 9/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3555 - mae: 2.3555 - val_loss: 2.3412 - val_mae: 2.3412
# Epoch 10/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3424 - mae: 2.3424 - val_loss: 2.3542 - val_mae: 2.3542
# Epoch 11/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3454 - mae: 2.3454 - val_loss: 2.3325 - val_mae: 2.3325
# Epoch 12/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3446 - mae: 2.3446 - val_loss: 2.3336 - val_mae: 2.3336
# Epoch 13/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3447 - mae: 2.3447 - val_loss: 2.3811 - val_mae: 2.3811
# Epoch 14/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3491 - mae: 2.3491 - val_loss: 2.3225 - val_mae: 2.3225
# Epoch 15/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3323 - mae: 2.3323 - val_loss: 2.3214 - val_mae: 2.3214
# Epoch 16/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3408 - mae: 2.3408 - val_loss: 2.3656 - val_mae: 2.3656
# Epoch 17/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3390 - mae: 2.3390 - val_loss: 2.3141 - val_mae: 2.3141
# Epoch 18/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3435 - mae: 2.3435 - val_loss: 2.3286 - val_mae: 2.3286
# Epoch 19/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3302 - mae: 2.3302 - val_loss: 2.3496 - val_mae: 2.3496
# Epoch 20/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3600 - mae: 2.3600 - val_loss: 2.3196 - val_mae: 2.3196
# Epoch 21/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3243 - mae: 2.3243 - val_loss: 2.3108 - val_mae: 2.3108
# Epoch 22/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3286 - mae: 2.3286 - val_loss: 2.4113 - val_mae: 2.4113
# Epoch 23/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3475 - mae: 2.3475 - val_loss: 2.3062 - val_mae: 2.3062
# Epoch 24/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3256 - mae: 2.3256 - val_loss: 2.3291 - val_mae: 2.3291
# Epoch 25/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3269 - mae: 2.3269 - val_loss: 2.3184 - val_mae: 2.3184
# Epoch 26/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3309 - mae: 2.3309 - val_loss: 2.3265 - val_mae: 2.3265
# Epoch 27/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3345 - mae: 2.3345 - val_loss: 2.3647 - val_mae: 2.3647
# Epoch 28/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3294 - mae: 2.3294 - val_loss: 2.3293 - val_mae: 2.3293
# Epoch 29/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3486 - mae: 2.3486 - val_loss: 2.3144 - val_mae: 2.3144
# Epoch 30/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3252 - mae: 2.3252 - val_loss: 2.3388 - val_mae: 2.3388
# Epoch 31/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3165 - mae: 2.3165 - val_loss: 2.3000 - val_mae: 2.3000
# Epoch 32/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3227 - mae: 2.3227 - val_loss: 2.3094 - val_mae: 2.3094
# Epoch 33/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3279 - mae: 2.3279 - val_loss: 2.3468 - val_mae: 2.3468
# Epoch 34/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3206 - mae: 2.3206 - val_loss: 2.3109 - val_mae: 2.3109
# Epoch 35/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3073 - mae: 2.3073 - val_loss: 2.2999 - val_mae: 2.2999
# Epoch 36/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3086 - mae: 2.3086 - val_loss: 2.3585 - val_mae: 2.3585
# Epoch 37/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3139 - mae: 2.3139 - val_loss: 2.3301 - val_mae: 2.3301
# Epoch 38/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3033 - mae: 2.3033 - val_loss: 2.2802 - val_mae: 2.2802
# Epoch 39/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3104 - mae: 2.3104 - val_loss: 2.2912 - val_mae: 2.2912
# Epoch 40/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3046 - mae: 2.3046 - val_loss: 2.3167 - val_mae: 2.3167
# Epoch 41/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3093 - mae: 2.3093 - val_loss: 2.2908 - val_mae: 2.2908
# Epoch 42/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3041 - mae: 2.3041 - val_loss: 2.2987 - val_mae: 2.2987
# Epoch 43/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3104 - mae: 2.3104 - val_loss: 2.3265 - val_mae: 2.3265
# Epoch 44/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2986 - mae: 2.2986 - val_loss: 2.3179 - val_mae: 2.3179
# Epoch 45/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3076 - mae: 2.3076 - val_loss: 2.2901 - val_mae: 2.2901
# Epoch 46/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3032 - mae: 2.3032 - val_loss: 2.2945 - val_mae: 2.2945
# Epoch 47/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3035 - mae: 2.3035 - val_loss: 2.3005 - val_mae: 2.3005
# Epoch 48/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3017 - mae: 2.3017 - val_loss: 2.2956 - val_mae: 2.2956
# Epoch 49/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3006 - mae: 2.3006 - val_loss: 2.2740 - val_mae: 2.2740
# Epoch 50/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3006 - mae: 2.3006 - val_loss: 2.2880 - val_mae: 2.2880

# %% [markdown]
# # And take a look at the results:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

err = hist.history['mae']
val_err = hist.history['val_mae']
epochs = range(1, len(err) + 1)

plt.plot(epochs, err, '-', label='Training MAE')
plt.plot(epochs, val_err, ':', label='Validation MAE')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(loc='upper right')
plt.plot()
# Out:
# []

# %% [markdown]
# # Last, but not least, let's make some predictions:

# %%
from sklearn.metrics import r2_score

r2_score(y, model.predict(x))
# Out:
# 729/729 [==============================] - 1s 1ms/step
# 0.7478308157084277

# %% [markdown]
# Estimate what it will cost to hire a taxi for a 2-mile trip at 5:00pm on a Friday afternoon:
# - day of the week `[ Monday:0, Tuesday:1, Wednesday:2, Thursday:3, Friday:4, Saturday:5, Sunday:6]`
# - time, military time
# - distance in miles

# %%
import numpy as np

# day of the week, time, and distance
model.add(Dense(128, activation='relu', input_dim=29))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='mae', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               2048
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 1)                 513
#
#  dense_3 (Dense)             (None, 128)               256
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 282,114
# Trainable params: 282,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # ✨ New Material

# %% [markdown]
# To talk about:
# - practicing building models
# - sensitive data
# - imbalanced datasets
# - saving and loading models

# %% [markdown]
# # Fraud Detection with Neural Networks
#
# Credit card companies use ML models to examine transactions in real time and identify ones that are likely to be fraudulent.
# - the features they use contain sensitive information (credit card numbers, purchase history, etc)
#
# ## 💬 Group Discussion:
# - the anonymity of the customers should be preserved somehow, while keeping as much data as possible. Any ideas how we might go about doing this?

# %% [markdown]
# > Go ahead and download the `creditcard.csv` file from Bb.
#
# - `Time` is the number of seconds elapsed since the first transaction
# - `Class` tells us whether the transaction is legitimate (0) or fraudulent (1)
# - `Amount` is the amount the transaction was for.
# - The other columns `V1` - `V28` were generated using PCA from information that isn't revelaed to us.

# %%
import pandas as pd

path = '/content/drive/MyDrive/datasets/creditcard.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %% [markdown]
# # Imbalanced Datasets:
#
# In the real world, we rarely get the privilege of working with nicely balanced datasets. This dataset is a great example of this.
#
# What do I mean by a __balanced dataset__?
# - relatively equal distribution of the classes we're trying to predict.
#
# How might we check to see if our dataset is balanced?

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# We'll use [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)'s `stratify` parameter to ensure that the ratio of legimate and fraudulent transactions is consisten in the training and the testing dataset:

# %%
from sklearn.model_selection import train_test_split

x = df.drop(['Time', 'Class'], axis=1)
y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)

# %% [markdown]
# # Exercise #1: Build our network
#
# What kind of machine learning are we doing here? Classifiation or regression?

# %% [markdown]
# Let's build a network that has:
# - `input_dim=29`
# - 1 hidden layer with 128 neurons
# - `relu` for the activation function of the hidden layer
# - a `Dense` output layer with a `sigmoid` activation function.
#
# when you're done, print out the summary of your model.

# %%
# your code here:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential() 

#build your model here:
model.add(Dense(128, activation='relu', input_dim=29))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               3840
#
#  dense_13 (Dense)            (None, 128)               16512
#
#  dense_14 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 20,481
# Trainable params: 20,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile your model with loss='binary_crossentropy', optimizer='adam', and metrics=['accuracy']
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# train your model for 10 epochs, with batch_size=100
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 2279/2279 [==============================] - 11s 4ms/step - loss: 0.0303 - accuracy: 0.9986 - val_loss: 0.0102 - val_accuracy: 0.9993
# Epoch 2/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0192 - accuracy: 0.9990 - val_loss: 0.0091 - val_accuracy: 0.9993
# Epoch 3/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0069 - accuracy: 0.9993 - val_loss: 0.0070 - val_accuracy: 0.9993
# Epoch 4/10
# 2279/2279 [==============================] - 8s 4ms/step - loss: 0.0069 - accuracy: 0.9993 - val_loss: 0.0042 - val_accuracy: 0.9993
# Epoch 5/10
# 2279/2279 [==============================] - 9s 4ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.0048 - val_accuracy: 0.9993
# Epoch 6/10
# 2279/2279 [==============================] - 9s 4ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0040 - val_accuracy: 0.9994
# Epoch 7/10
# 2279/2279 [==============================] - 9s 4ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0040 - val_accuracy: 0.9994
# Epoch 8/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.0037 - val_accuracy: 0.9994
# Epoch 9/10
# 2279/2279 [==============================] - 9s 4ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 0.9992
# Epoch 10/10
# 2279/2279 [==============================] - 8s 4ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.0057 - val_accuracy: 0.9993

# %% [markdown]
# Plot the training accuracy and validation acuracy:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# Visualize the results as a confusion matrix:

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt

sns.reset_orig()
y_predicted = model.predict(x_test) > 0.5 # it will be 1 if > 0.5 and 0 otherwise
labels = ['Legitimate', 'Fraudulent']

cm = confusion_matrix(y_test, y_predicted, labels=df.Class.unique())
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labels)
disp.plot()
plt.show()
# Out:
# 1781/1781 [==============================] - 3s 2ms/step

# %% [markdown]
# Your results will vary, but in this example, the model caught 74 of 98 fraudulent cases, and missclassified 9 legitimate charges as fraudulent.
#
# What is the accuracy of fraudulent cases?

# %%
total_fraudulent = 31 + 67
correct = 67
correct / total_fraudulent
# Out:
# 0.6836734693877551

# %% [markdown]
# ## Things to consider:
#
# - how might we make predictions with this model?

# %% [markdown]
# # Multiclass Classification with Neural Networks:
#
# We just did an example where we were doing `binary classification`. What things do we need to change to be able to do `multiclass classification`?

# %% [markdown]
# - the output layer needs to contain _one neuron per output class_
# - the output layer should use _______ activation instead of `sigmoid`.
# - the loss function wil be `sparse_cateogrical_crossentropy`

# %% [markdown]
# ## Training a Neural Network to Recognize Faces
#
# We're going to use the [Labeled Faces in the Wild (LFW)](http://vis-www.cs.umass.edu/lfw/) dataset.
#
# We'll learn that Convolutional Neural Networks will be able to do a better job on this data than regular Neural networks. But let's give it a shot:

# %% [markdown]
# # Load the dataset:
#
# This dataset contains more than 13,000 facial images collected from tne internet.
#
# Of the more than 5000 people represented in the dataset 1680 have two or more facial images, while only five have 100 or more.
#
# We'll set the minimum number of faces per person to 100, which means that five sets of faces corresponding to five famous people will be imported.

# %%
import pandas as pd
from sklearn.datasets import fetch_lfw_people

faces = fetch_lfw_people(min_faces_per_person=100, slice_=None)
faces.images = faces.images[:, 35:97, 39:86]
faces.data = faces.images.reshape(faces.images.shape[0], faces.images.shape[1] * faces.images.shape[2])
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)

print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1140 facial images were loaded. AFter cropping, each image measures 47x 62 pixels for a total of 2914 pixels per image. That means we're workign with a dataset containing 2914 feature columns.
#
# Use the folloiwng code to show the first 24 images in the dataset and the poeple to whom the faces belong.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# ## 💬 Group Exercise
#
# Check the balance of the dataset:

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-67d2bf93f5a0> in <cell line: 1>()
# ----> 1 faces.data.target.shape()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'target'

# %% [markdown]
# The dataset is not very well balanced, and that's a concern because classification models are best trained with balanced datasets. Use the following code to build a dataset containing 100 images of each person.

# %%
import numpy as np

mask = np.zeros(faces.target.shape, dtype=bool)

for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
    
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %% [markdown]
# ## Split the data for training and testing:

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_faces, y_faces, train_size=0.8, stratify=y_faces, random_state=0)

# %% [markdown]
# ## Build and train a neural network:
#
# Start by using Keras to build and train an eural network containnig:
# - one hidden layer with 512 neurons.
# - `sparse_categorical_crossentropy` as the loss function
# - a `softmax` activation function on our output layer since this is a multiclass classification task
# -  `adam` as our optimization algorithm

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
 
model = Sequential()
# build your model here:
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 512)               1492480
#
#  dense_16 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, train your model:

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 11ms/step - loss: 3.0756 - accuracy: 0.2125 - val_loss: 1.8003 - val_accuracy: 0.3200
# Epoch 2/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5158 - accuracy: 0.3500 - val_loss: 1.6893 - val_accuracy: 0.3800
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4180 - accuracy: 0.4500 - val_loss: 1.3015 - val_accuracy: 0.5600
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2626 - accuracy: 0.4975 - val_loss: 1.2597 - val_accuracy: 0.4400
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1964 - accuracy: 0.5400 - val_loss: 1.4584 - val_accuracy: 0.2800
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.0382 - accuracy: 0.6200 - val_loss: 1.0964 - val_accuracy: 0.5900
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9076 - accuracy: 0.7075 - val_loss: 0.9661 - val_accuracy: 0.6800
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8486 - accuracy: 0.7650 - val_loss: 0.9865 - val_accuracy: 0.6000
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7690 - accuracy: 0.7825 - val_loss: 0.9465 - val_accuracy: 0.6300
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7419 - accuracy: 0.7725 - val_loss: 1.2953 - val_accuracy: 0.5900
# Epoch 11/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9778 - accuracy: 0.6550 - val_loss: 1.2813 - val_accuracy: 0.4600
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9283 - accuracy: 0.6350 - val_loss: 1.0271 - val_accuracy: 0.5500
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7468 - accuracy: 0.7250 - val_loss: 0.7589 - val_accuracy: 0.7100
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6079 - accuracy: 0.8000 - val_loss: 0.9283 - val_accuracy: 0.6400
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5691 - accuracy: 0.8300 - val_loss: 0.7612 - val_accuracy: 0.7200
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5432 - accuracy: 0.8450 - val_loss: 0.7799 - val_accuracy: 0.7100
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5155 - accuracy: 0.8650 - val_loss: 0.6810 - val_accuracy: 0.6800
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4978 - accuracy: 0.8550 - val_loss: 0.9466 - val_accuracy: 0.6700
# Epoch 19/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5922 - accuracy: 0.7925 - val_loss: 1.0745 - val_accuracy: 0.6700
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4895 - accuracy: 0.8500 - val_loss: 0.6779 - val_accuracy: 0.7500
# Epoch 21/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4581 - accuracy: 0.8500 - val_loss: 0.9511 - val_accuracy: 0.6500
# Epoch 22/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.7950 - val_loss: 0.8505 - val_accuracy: 0.6900
# Epoch 23/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4984 - accuracy: 0.8250 - val_loss: 1.0601 - val_accuracy: 0.6700
# Epoch 24/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.8500 - val_loss: 0.9289 - val_accuracy: 0.7000
# Epoch 25/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4184 - accuracy: 0.8650 - val_loss: 0.8755 - val_accuracy: 0.6900
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3817 - accuracy: 0.8725 - val_loss: 0.9758 - val_accuracy: 0.6600
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3253 - accuracy: 0.9100 - val_loss: 0.8707 - val_accuracy: 0.7200
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3146 - accuracy: 0.9275 - val_loss: 0.8872 - val_accuracy: 0.7200
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3891 - accuracy: 0.8725 - val_loss: 0.6719 - val_accuracy: 0.7600
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2842 - accuracy: 0.9175 - val_loss: 0.6468 - val_accuracy: 0.7700
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2620 - accuracy: 0.9325 - val_loss: 0.5547 - val_accuracy: 0.8000
# Epoch 32/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2498 - accuracy: 0.9350 - val_loss: 0.7300 - val_accuracy: 0.7100
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3795 - accuracy: 0.8750 - val_loss: 0.6299 - val_accuracy: 0.7400
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2810 - accuracy: 0.9075 - val_loss: 0.7720 - val_accuracy: 0.7300
# Epoch 35/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2627 - accuracy: 0.9200 - val_loss: 1.2065 - val_accuracy: 0.6100
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3255 - accuracy: 0.8950 - val_loss: 1.1839 - val_accuracy: 0.6100
# Epoch 37/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2402 - accuracy: 0.9325 - val_loss: 0.6450 - val_accuracy: 0.7300
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.9525 - val_loss: 0.6134 - val_accuracy: 0.7400
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2067 - accuracy: 0.9700 - val_loss: 0.7146 - val_accuracy: 0.7400
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2863 - accuracy: 0.9025 - val_loss: 0.8497 - val_accuracy: 0.7500
# Epoch 41/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4237 - accuracy: 0.8225 - val_loss: 0.7367 - val_accuracy: 0.7000
# Epoch 42/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1959 - accuracy: 0.9475 - val_loss: 0.6663 - val_accuracy: 0.7900
# Epoch 43/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2257 - accuracy: 0.9325 - val_loss: 0.6151 - val_accuracy: 0.8000
# Epoch 44/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1800 - accuracy: 0.9625 - val_loss: 1.0230 - val_accuracy: 0.6900
# Epoch 45/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2904 - accuracy: 0.8975 - val_loss: 0.8112 - val_accuracy: 0.7400
# Epoch 46/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9450 - val_loss: 0.6807 - val_accuracy: 0.7700
# Epoch 47/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2344 - accuracy: 0.9300 - val_loss: 0.6524 - val_accuracy: 0.7600
# Epoch 48/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.9375 - val_loss: 0.7552 - val_accuracy: 0.7300
# Epoch 49/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2225 - accuracy: 0.9175 - val_loss: 0.5474 - val_accuracy: 0.8100
# Epoch 50/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1846 - accuracy: 0.9400 - val_loss: 0.6455 - val_accuracy: 0.7500
# Epoch 51/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1755 - accuracy: 0.9550 - val_loss: 0.7649 - val_accuracy: 0.7800
# Epoch 52/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1556 - accuracy: 0.9600 - val_loss: 0.5821 - val_accuracy: 0.7900
# Epoch 53/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1501 - accuracy: 0.9575 - val_loss: 0.6725 - val_accuracy: 0.7700
# Epoch 54/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2003 - accuracy: 0.9275 - val_loss: 0.6732 - val_accuracy: 0.6700
# Epoch 55/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1181 - accuracy: 0.9750 - val_loss: 0.5063 - val_accuracy: 0.8300
# Epoch 56/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0898 - accuracy: 0.9850 - val_loss: 0.5206 - val_accuracy: 0.8200
# Epoch 57/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0815 - accuracy: 0.9900 - val_loss: 0.7125 - val_accuracy: 0.7400
# Epoch 58/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0805 - accuracy: 0.9950 - val_loss: 0.6733 - val_accuracy: 0.7900
# Epoch 59/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1001 - accuracy: 0.9850 - val_loss: 0.5882 - val_accuracy: 0.7700
# Epoch 60/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0970 - accuracy: 0.9850 - val_loss: 0.6392 - val_accuracy: 0.8000
# Epoch 61/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0962 - accuracy: 0.9800 - val_loss: 0.6733 - val_accuracy: 0.7900
# Epoch 62/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1850 - accuracy: 0.9425 - val_loss: 1.2451 - val_accuracy: 0.6500
# Epoch 63/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1335 - accuracy: 0.9700 - val_loss: 0.9209 - val_accuracy: 0.7300
# Epoch 64/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0779 - accuracy: 0.9925 - val_loss: 0.6596 - val_accuracy: 0.8000
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9900 - val_loss: 0.7359 - val_accuracy: 0.7700
# Epoch 66/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0638 - accuracy: 0.9875 - val_loss: 0.5722 - val_accuracy: 0.8100
# Epoch 67/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.6739 - val_accuracy: 0.7900
# Epoch 68/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0555 - accuracy: 0.9950 - val_loss: 0.7114 - val_accuracy: 0.7800
# Epoch 69/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0570 - accuracy: 0.9975 - val_loss: 0.5623 - val_accuracy: 0.8200
# Epoch 70/100
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.5444 - val_accuracy: 0.7800
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.7957 - val_accuracy: 0.7300
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0847 - accuracy: 0.9775 - val_loss: 0.8100 - val_accuracy: 0.7500
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0629 - accuracy: 0.9950 - val_loss: 0.6284 - val_accuracy: 0.7900
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.6217 - val_accuracy: 0.8000
# Epoch 75/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 1.0000 - val_loss: 0.6415 - val_accuracy: 0.8000
# Epoch 76/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.6038 - val_accuracy: 0.8300
# Epoch 77/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.5837 - val_accuracy: 0.8100
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.7090 - val_accuracy: 0.7900
# Epoch 79/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.5518 - val_accuracy: 0.8200
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9900 - val_loss: 0.7432 - val_accuracy: 0.7900
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9900 - val_loss: 0.5848 - val_accuracy: 0.7700
# Epoch 82/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0462 - accuracy: 0.9950 - val_loss: 0.6642 - val_accuracy: 0.8100
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9925 - val_loss: 0.6362 - val_accuracy: 0.8200
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 0.9950 - val_loss: 0.7530 - val_accuracy: 0.7800
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0536 - accuracy: 0.9925 - val_loss: 0.6212 - val_accuracy: 0.8200
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9975 - val_loss: 0.5270 - val_accuracy: 0.8000
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.7009 - val_accuracy: 0.8200
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.8300
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.5969 - val_accuracy: 0.8100
# Epoch 90/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.6099 - val_accuracy: 0.8100
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.5673 - val_accuracy: 0.8300
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.6164 - val_accuracy: 0.8000
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.5651 - val_accuracy: 0.8200
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.6217 - val_accuracy: 0.8400
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.5806 - val_accuracy: 0.8200
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9950 - val_loss: 0.7777 - val_accuracy: 0.7600
# Epoch 97/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.6425 - val_accuracy: 0.8100
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.5777 - val_accuracy: 0.8200
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.5754 - val_accuracy: 0.7900
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.6754 - val_accuracy: 0.8400

# %% [markdown]
# Plot the training and validation accuracy:

# %%
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# And... finally, use the test data to generate a confusion matrix to visualize how the network performs.

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import sklearn
print(sklearn.__version__)

sns.reset_orig()
y_pred = model.predict(x_test)

cm = confusion_matrix(y_test, y_pred.argmax(axis=1))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=faces.target_names)
disp.plot()
# Out:
# 1.2.2
# 4/4 [==============================] - 0s 10ms/step

# %% [markdown]
# # Keras Callbacks:
#
# Want to check in on your network while it's training? Keras's [_callbacks API_](https://keras.io/api/callbacks/) allows us to do so

# %% [markdown]
# Let's demo the callbacks API using MNIST, a very common computer vision dataset of handwritten digit recognition.

# %%
from tensorflow.keras.datasets import mnist

(train_images, y_train), (test_images, y_test) = mnist.load_data()
print('train_images: ' + str(train_images.shape))
print('y_train: ' + str(y_train.shape))
print('test_images: ' + str(test_images.shape))
print('y_test: ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# train_images: (60000, 28, 28)
# y_train: (60000,)
# test_images: (10000, 28, 28)
# y_test: (10000,)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
plt.imshow(train_images[0], cmap=plt.cm.gray_r)

# %% [markdown]
# Plot the first 50 images from MNIST:

# %%
fig, axes = plt.subplots(5, 10, figsize=(12, 7), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(train_images[i], cmap=plt.cm.gray_r)
    ax.text(0.45, 1.05, str(y_train[i]), transform=ax.transAxes)

# %% [markdown]
# ## Check to make sure it's balanced:

# %%
plt.xticks([])
plt.hist(y_train, rwidth=0.9)
# Out:
# (array([5923., 6742., 5958., 6131., 5842., 5421., 5918., 6265., 5851.,
#         5949.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Prepare the input data by flattening the pixel arrays and normalizing the pixel valuse by dividing thben by 255.

# %%
x_train = train_images.reshape(60000, 28 * 28) / 255
x_test = test_images.reshape(10000, 28 * 28) / 255

# %% [markdown]
# Create a neural network with a `softmax` output layer for the classification:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=28 * 28))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Call `fit` to train the model. Stop training if the validation accuracy fails to imporve for 5 consecutive epochs, and reduce the learning rate if the validation accuracy fails to imporve for 3 consecutive epochs.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3)

hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=50,
                 callbacks=[early_stop, reduce_lr])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2842 - accuracy: 0.9205 - val_loss: 0.1500 - val_accuracy: 0.9549
# Epoch 2/100
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.1272 - accuracy: 0.9630 - val_loss: 0.1085 - val_accuracy: 0.9672
# Epoch 3/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0889 - accuracy: 0.9734 - val_loss: 0.0826 - val_accuracy: 0.9763
# Epoch 4/100
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.0665 - accuracy: 0.9800 - val_loss: 0.0770 - val_accuracy: 0.9767
# Epoch 5/100
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.0517 - accuracy: 0.9843 - val_loss: 0.0780 - val_accuracy: 0.9755
# Epoch 6/100
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0757 - val_accuracy: 0.9773
# Epoch 7/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0344 - accuracy: 0.9893 - val_loss: 0.0759 - val_accuracy: 0.9783
# Epoch 8/100
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.0812 - val_accuracy: 0.9768
# Epoch 9/100
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.0718 - val_accuracy: 0.9790
# Epoch 10/100
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.0759 - val_accuracy: 0.9778
# Epoch 11/100
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0714 - val_accuracy: 0.9803
# Epoch 12/100
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0802 - val_accuracy: 0.9768
# Epoch 13/100
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0811 - val_accuracy: 0.9782
# Epoch 14/100
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0824 - val_accuracy: 0.9794
# Epoch 15/100
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.0790 - val_accuracy: 0.9794
# Epoch 16/100
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0767 - val_accuracy: 0.9813
# Epoch 17/100
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0795 - val_accuracy: 0.9800
# Epoch 18/100
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0816 - val_accuracy: 0.9797
# Epoch 19/100
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0847 - val_accuracy: 0.9792
# Epoch 20/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9814
# Epoch 21/100
# 60000/60000 [==============================] - 4s 68us/sample - loss: 7.7828e-04 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9807
# Epoch 22/100
# 60000/60000 [==============================] - 4s 70us/sample - loss: 7.8139e-04 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9804
# Epoch 23/100
# 60000/60000 [==============================] - 4s 67us/sample - loss: 6.1029e-04 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9805
# Epoch 24/100
# 60000/60000 [==============================] - 4s 68us/sample - loss: 4.3717e-04 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9813
# Epoch 25/100
# 60000/60000 [==============================] - 4s 69us/sample - loss: 3.9055e-04 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9814

# %%
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []
